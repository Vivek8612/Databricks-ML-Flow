# %% [markdown]
# #Notebook to test the execution of the notebooks in the workshop
# Please execute this notebook in advance of the workshop, it runs some prep that ensures all notebooks execute
#
# This notebook runs on Databricks ML Runtime 7.0 with %pip/%conda magic commands enabled as of this writing.

# %%
#Run 01
try:
  dbutils.notebook.run("../01 Intro to DS on Databricks/01 DS Features",0)
except:
  print("Error Running 01")

# %%
#Run 02
try:
  dbutils.notebook.run("../02 MLflow/01-MLflow-Overview",0)
  dbutils.notebook.run("../02 MLflow/02-Experiment-Tracking",0)
  #dbutils.notebook.run("../02 MLflow/03-Packaging-ML-Projects",0)
  dbutils.notebook.run("../02 MLflow/04-Model-Management",0)
  #dbutils.notebook.run("../02 MLflow/05-Model-Registry",0)
except:
  print("Error Running 02")

# %%
# Run 02 - Lab solutions
try:
  dbutils.notebook.run("../02 MLflow/Solutions/Labs/02-Lab", 0)
  #dbutils.notebook.run("../02 MLflow/Solutions/Labs/03-Lab", 0)
  dbutils.notebook.run("../02 MLflow/Solutions/Labs/04-Lab", 0)
except:
  print("An error occurred while testing 02 MLflow - Lab Solutions")

# %%
#Run 05
try:
  print("Skipping Koalas test (notebooks contain intentional errors)")
  #dbutils.notebook.run("../05 Koalas/01 Koalas Working Demo",0)
  #dbutils.notebook.run("../05 Koalas/02 Alternative Simple Koalas Demo",0)
except:
  print("Error Running 05")
